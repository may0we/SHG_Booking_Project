# %% [markdown]
# <a href="https://colab.research.google.com/github/may0we/SHG_Booking_Project/blob/main/Gradient_boost0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import pandas as pd
import os
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Download latest version
path = kagglehub.dataset_download("rishikeshkonapure/home-loan-approval")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/home-loan-approval

# %%
test_url = os.path.join(path, os.listdir(path)[0])
train_url = os.path.join(path, os.listdir(path)[1])

test_data = pd.read_csv(test_url)
train_data = pd.read_csv(train_url)

# %%
train_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
os.listdir(path)
# Out:
# ['loan_sanction_test.csv', 'loan_sanction_train.csv']

# %%
print(test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
# None

# %%
print(test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
# None

# %%
mode_value_gender = test_data['Gender'].mode()[0]
test_data['Gender'].fillna(mode_value_gender, inplace=True)
# Out:
# /tmp/ipython-input-741239152.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['Gender'].fillna(mode_value_gender, inplace=True)

# %%
e_value_gender = train_data['Gender'].mode()[0]
train_data['Gender'].fillna(mode_value_gender, inplace=True)
# Out:
# /tmp/ipython-input-2073997683.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['Gender'].fillna(mode_value_gender, inplace=True)

# %%
print(test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             367 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB
# None

# %%
test_data['Loan_Amount_Term'].fillna(test_data['Loan_Amount_Term'].median(), inplace=True)
# Out:
# /tmp/ipython-input-474021403.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['Loan_Amount_Term'].fillna(test_data['Loan_Amount_Term'].median(), inplace=True)

# %%
train_data['Loan_Amount_Term'].fillna(train_data['Loan_Amount_Term'].median(), inplace=True)
# Out:
# /tmp/ipython-input-4087288876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['Loan_Amount_Term'].fillna(train_data['Loan_Amount_Term'].median(), inplace=True)

# %%
print(test_data.isnull().sum())
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      0
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
print(train_data.isnull().sum())
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
test_data['Credit_History'].fillna(test_data['Credit_History'].median(), inplace=True)
# Out:
# /tmp/ipython-input-1262370913.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['Credit_History'].fillna(test_data['Credit_History'].median(), inplace=True)

# %%
train_data['Credit_History'].fillna(train_data['Credit_History'].median(), inplace=True)
# Out:
# /tmp/ipython-input-2724122362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['Credit_History'].fillna(train_data['Credit_History'].median(), inplace=True)

# %%
print(test_data.isnull().sum())
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
print(train_data.isnull().sum())
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# dropping the empty cells

test_data.dropna(inplace=True)

train_data.dropna(inplace=True)

# %%
train_data.reset_index(drop=True, inplace=True)

train_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 543  LP002978  Female      No          0      Graduate            No
# 544  LP002979    Male     Yes         3+      Graduate            No
# 545  LP002983    Male     Yes          1      Graduate            No
# 546  LP002984    Male     Yes          2      Graduate            No
# 547  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
test_data.reset_index(drop=True, inplace=True)

test_data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 325  LP002971   Male     Yes         3+  Not Graduate           Yes
# 326  LP002975   Male     Yes          0      Graduate            No
# 327  LP002980   Male      No          0      Graduate            No
# 328  LP002986   Male     Yes          0      Graduate            No
# 329  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
train_data.to_csv('Cleaned_train_data.csv')

# %%
# encode the categorical variables

categorical_columns = list(train_data.select_dtypes(include ='object').columns)
for column in categorical_columns:
    encoder = LabelEncoder()
    train_data[column] = encoder.fit_transform(train_data[column])

train_data.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        0       1        1           1          0              0
# 1        1       1        1           0          0              1
# 2        2       1        1           0          1              0
# 3        3       1        0           0          0              0
# 4        4       1        1           2          0              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              0            0
# 1             1.0              2            1
# ...

# %%
# split the dataset

X = data.drop(columns=['Loan_Status'])
y = data['Loan_Status']

# train and test split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,
                                                  random_state=23, stratify=y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-166826097.py in <cell line: 0>()
#       1 # split the dataset
#       2
# ----> 3 X = data.drop(columns=['Loan_Status'])
#       4 y = data['Loan_Status']
#       5
#
# NameError: name 'data' is not defined

# %%
# split the dataset
from sklearn.model_selection import train_test_split

X = train_data.drop(columns=['Loan_ID', 'Loan_Status'])
y = train_data['Loan_Status']

# train and test split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,
                                                  random_state=23, stratify=y)

# %%
# Scale the dataset
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
columns = X_train.columns
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# convert to dataframe
X_train = pd.DataFrame(data=X_train, columns=columns)
X_test = pd.DataFrame(data=X_test, columns=columns)

# %%
# train the model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=23, n_estimators=2, max_depth=2)
model.fit(X_train, y_train)
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# %%
# Evaluate the model Output

train_classification = classification_report(y_train, train_preds)# get classification report for train predictions
test_classification = classification_report(y_test, test_preds)# get classification report for test predictions

print(f'train set:\n {classification_report(y_train, train_preds)}')
print(f'test set:\n {classification_report(y_test, test_preds)}')
# Out:
# train set:
#                precision    recall  f1-score   support
#
#            0       0.92      0.43      0.58       133
#            1       0.80      0.98      0.88       305
#
#     accuracy                           0.82       438
#    macro avg       0.86      0.71      0.73       438
# weighted avg       0.83      0.82      0.79       438
#
# test set:
#                precision    recall  f1-score   support
#
#            0       0.88      0.44      0.59        34
#            1       0.80      0.97      0.88        76
#
#     accuracy                           0.81       110
#    macro avg       0.84      0.71      0.73       110
# weighted avg       0.82      0.81      0.79       110
